# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Constructure World Championschip

# %%
constructure = pd.read_csv('./constructure-world-championship.csv')
constructure
# Out:
#      Season Constructor    Class
# 0      2021      Yamaha  MotoGP™
# 1      2021       Kalex   Moto2™
# 2      2021         KTM   Moto3™
# 3      2021    Energica   MotoE™
# 4      2020      Suzuki  MotoGP™
# ..      ...         ...      ...
# 279    1950   Velocette    350cc
# 280    1949         AJS  MotoGP™
# 281    1949  Moto Guzzi    250cc
# 282    1949     Mondial    125cc
# 283    1949   Velocette    350cc
#
# [284 rows x 3 columns]

# %%
constructure.describe()
# Out:
#             Season
# count   284.000000
# mean   1982.098592
# std      20.512621
# min    1949.000000
# 25%    1965.000000
# 50%    1979.500000
# 75%    1999.000000
# max    2021.000000

# %%
constructure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       284 non-null    int64
#  1   Constructor  284 non-null    object
#  2   Class        284 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 6.8+ KB

# %% [markdown]
# # Events Held

# %%
gp_events = pd.read_csv('./grand-prix-events-held.csv')
gp_events
# Out:
#     Times                            Track Country
# 0     280                 TT Circuit Assen      NL
# 1     168                Automotodrom Brno      CZ
# 2     131                Spa-Francorchamps      BE
# 3     125                      Sachsenring      DE
# 4     118  Circuito de Jerez - Angel Nieto      ES
# ..    ...                              ...     ...
# 67      3                       Interlagos      BR
# 68      3                      Magny Cours      FR
# 69      3                            Johor      MY
# 70      3                             Albi      FR
# 71      2                         Schotten      DE
#
# [72 rows x 3 columns]

# %%
gp_events.sort_values('Country')
# Out:
#     Times                      Track Country
# 41     21        Termas de Río Hondo      AR
# 34     31            Oscar A. Galvez      AR
# 32     37  Red Bull Ring - Spielberg      AT
# 19     71               Salzburgring      AT
# 45     18              Eastern Creek      AU
# ..    ...                        ...     ...
# 47     12                 San Carlos      VE
# 33     36                    Opatija      YU
# 28     46                     Rijeka      YU
# 44     18            Phakisa Freeway      ZA
# 51      9                    Kyalami      ZA
#
# [72 rows x 3 columns]

# %%
gp_events.describe()
# Out:
#             Times
# count   72.000000
# mean    46.583333
# std     49.182257
# min      2.000000
# 25%      8.000000
# 50%     27.500000
# 75%     72.000000
# max    280.000000

# %%
gp_events.info
# Out:
# <bound method DataFrame.info of     Times                            Track Country
# 0     280                 TT Circuit Assen      NL
# 1     168                Automotodrom Brno      CZ
# 2     131                Spa-Francorchamps      BE
# 3     125                      Sachsenring      DE
# 4     118  Circuito de Jerez - Angel Nieto      ES
# ..    ...                              ...     ...
# 67      3                       Interlagos      BR
# 68      3                      Magny Cours      FR
# 69      3                            Johor      MY
# 70      3                             Albi      FR
# 71      2                         Schotten      DE
#
# [72 rows x 3 columns]>

# %% [markdown]
# # Grand prix race winners

# %%
gp_race = pd.read_csv('./grand-prix-race-winners.csv')
gp_race
# Out:
#                       Circuit    Class Constructor Country  \
# 0     Circuit Of The Americas   Moto3™         KTM      ES
# 1     Circuit Of The Americas   Moto2™       Kalex      IT
# 2     Circuit Of The Americas  MotoGP™      Ducati      IT
# 3         Termas de Río Hondo   Moto3™      GASGAS      ES
# 4         Termas de Río Hondo  MotoGP™     Aprilia      ES
# ...                       ...      ...         ...     ...
# 3078                    Berne  MotoGP™         AJS      GB
# 3079                    Berne    125cc     Mondial      IT
# 3080              Isle of Man  MotoGP™      Norton      GB
# 3081              Isle of Man    250cc  Moto Guzzi      IE
# 3082              Isle of Man    350cc   Velocette      GB
#
#                     Rider  Season
# 0             Jaume Masia    2022
# 1           Tony Arbolino    2022
# 2         Enea Bastianini    2022
# 3           Sergio Garcia    2022
# 4         Aleix Espargaro    2022
# ...                   ...     ...
# ...

# %%
gp_race.describe()
# Out:
#             Season
# count  3083.000000
# mean   1988.363283
# std      20.185907
# min    1949.000000
# 25%    1972.000000
# 50%    1988.000000
# 75%    2007.000000
# max    2022.000000

# %%
gp_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3083 entries, 0 to 3082
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Circuit      3083 non-null   object
#  1   Class        3083 non-null   object
#  2   Constructor  3055 non-null   object
#  3   Country      3018 non-null   object
#  4   Rider        3083 non-null   object
#  5   Season       3083 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 144.6+ KB

# %% [markdown]
# # Riders Position

# %%
riders_finishing = pd.read_csv('./riders-finishing-positions.csv')
riders_finishing
# Out:
#                  Rider  Victories  NumberofSecond  NumberofThird  Numberof4th  \
# 0     Giacomo Agostini        122              67             53           48
# 1      Valentino Rossi        115              52             47           38
# 2          Angel Nieto         90              51             40           35
# 3         Marc Marquez         85              44             36           28
# 4        Mike Hailwood         76              41             33           26
# ..                 ...        ...             ...            ...          ...
# 389  Tetsuta Nagashima          1               1              2            2
# 390   Gyula Marsovszky          1               1              2            2
# 391       Regis Laconi          1               1              2            2
# 392           Can öncü          1               1              2            2
# 393          R. Creith          1               1              2            2
#
# ...

# %%
riders_finishing.fillna(0)
# Out:
#                  Rider  Victories  NumberofSecond  NumberofThird  Numberof4th  \
# 0     Giacomo Agostini        122              67             53           48
# 1      Valentino Rossi        115              52             47           38
# 2          Angel Nieto         90              51             40           35
# 3         Marc Marquez         85              44             36           28
# 4        Mike Hailwood         76              41             33           26
# ..                 ...        ...             ...            ...          ...
# 389  Tetsuta Nagashima          1               1              2            2
# 390   Gyula Marsovszky          1               1              2            2
# 391       Regis Laconi          1               1              2            2
# 392           Can öncü          1               1              2            2
# 393          R. Creith          1               1              2            2
#
# ...

# %%
riders_finishing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rider           394 non-null    object
#  1   Victories       394 non-null    int64
#  2   NumberofSecond  394 non-null    int64
#  3   NumberofThird   394 non-null    int64
#  4   Numberof4th     394 non-null    int64
#  5   Numberof5th     394 non-null    int64
#  6   Numberof6th     394 non-null    int64
#  7   Country         390 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 24.8+ KB

# %%
riders_finishing.describe()
# Out:
#         Victories  NumberofSecond  NumberofThird  Numberof4th  Numberof5th  \
# count  394.000000      394.000000     394.000000   394.000000   394.000000
# mean     8.340102        7.994924       7.609137     7.258883     6.860406
# std     14.046852        8.536703       6.419953     5.441709     4.660298
# min      1.000000        1.000000       2.000000     2.000000     2.000000
# 25%      1.000000        3.000000       3.000000     3.000000     4.000000
# 50%      4.000000        5.000000       6.000000     6.000000     5.000000
# 75%      9.000000       10.000000      10.000000     9.000000     9.000000
# max    122.000000       67.000000      53.000000    48.000000    34.000000
#
#        Numberof6th
# count   394.000000
# mean      6.583756
# std       4.027809
# min       2.000000
# 25%       3.000000
# 50%       5.000000
# 75%       8.000000
# max      24.000000

# %%
riders_finishing.corr()
# Out:
#                 Victories  NumberofSecond  NumberofThird  Numberof4th  \
# Victories        1.000000        0.968416       0.963025     0.951227
# NumberofSecond   0.968416        1.000000       0.988985     0.986416
# NumberofThird    0.963025        0.988985       1.000000     0.994553
# Numberof4th      0.951227        0.986416       0.994553     1.000000
# Numberof5th      0.926339        0.984124       0.984553     0.984926
# Numberof6th      0.885389        0.963603       0.965123     0.965592
#
#                 Numberof5th  Numberof6th
# Victories          0.926339     0.885389
# NumberofSecond     0.984124     0.963603
# NumberofThird      0.984553     0.965123
# Numberof4th        0.984926     0.965592
# Numberof5th        1.000000     0.988367
# Numberof6th        0.988367     1.000000

# %% [markdown]
# # Riders Info

# %%
riders_info=pd.read_csv('./riders-info.csv')
riders_info
# Out:
#     Riders All Time in All Classes  Victories  2nd places  3rd places  \
# 0                 AGOSTINI Giacomo        122        35.0         2.0
# 1                  ROSSI Valentino        115        67.0        53.0
# 2                      NIETO Angel         90        35.0        14.0
# 3                     MARQUEZ Marc         85        36.0        17.0
# 4                    HAILWOOD Mike         76        25.0        11.0
# ..                             ...        ...         ...         ...
# 363                    ROSSI Louis          1         NaN         NaN
# 364                    LEONI Guido          1         NaN         NaN
# 365             FELGENHEIER Roland          1         NaN         NaN
# 366                    AUREAL Jean          1         NaN         NaN
# 367                 CARPENTER Phil          1         NaN         NaN
#
#      Pole positions from '74 to 2022  Race fastest lap to 2022  \
# ...

# %%
riders_info_c = riders_info.fillna(0)
riders_info_c
# Out:
#     Riders All Time in All Classes  Victories  2nd places  3rd places  \
# 0                 AGOSTINI Giacomo        122        35.0         2.0
# 1                  ROSSI Valentino        115        67.0        53.0
# 2                      NIETO Angel         90        35.0        14.0
# 3                     MARQUEZ Marc         85        36.0        17.0
# 4                    HAILWOOD Mike         76        25.0        11.0
# ..                             ...        ...         ...         ...
# 363                    ROSSI Louis          1         0.0         0.0
# 364                    LEONI Guido          1         0.0         0.0
# 365             FELGENHEIER Roland          1         0.0         0.0
# 366                    AUREAL Jean          1         0.0         0.0
# 367                 CARPENTER Phil          1         0.0         0.0
#
#      Pole positions from '74 to 2022  Race fastest lap to 2022  \
# ...

# %%
riders_info_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Riders All Time in All Classes   368 non-null    object
#  1   Victories                        368 non-null    int64
#  2   2nd places                       368 non-null    float64
#  3   3rd places                       368 non-null    float64
#  4   Pole positions from '74 to 2022  368 non-null    float64
#  5   Race fastest lap to 2022         368 non-null    float64
#  6   World Championships              368 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 20.2+ KB

# %%
riders_info_c.describe()
# Out:
#         Victories  2nd places  3rd places  Pole positions from '74 to 2022  \
# count  368.000000  368.000000  368.000000                       368.000000
# mean     8.679348    7.826087    7.016304                         6.000000
# std     14.460711    9.022054    7.071820                        11.095572
# min      1.000000    0.000000    0.000000                         0.000000
# 25%      1.000000    2.000000    2.000000                         0.000000
# 50%      4.000000    5.000000    5.000000                         1.000000
# 75%      9.250000   10.000000   10.000000                         7.000000
# max    122.000000   67.000000   53.000000                        90.000000
#
#        Race fastest lap to 2022  World Championships
# count                368.000000            368.00000
# mean                   7.649457              0.73913
# std                   13.038800              1.74143
# min                    0.000000              0.00000
# ...

# %%
riders_info_c.corr()
# Out:
#                                  Victories  2nd places  3rd places  \
# Victories                         1.000000    0.800686    0.580136
# 2nd places                        0.800686    1.000000    0.823005
# 3rd places                        0.580136    0.823005    1.000000
# Pole positions from '74 to 2022   0.692807    0.714619    0.607842
# Race fastest lap to 2022          0.958650    0.777982    0.573283
# World Championships               0.907953    0.658043    0.399272
#
#                                  Pole positions from '74 to 2022  \
# Victories                                               0.692807
# 2nd places                                              0.714619
# 3rd places                                              0.607842
# Pole positions from '74 to 2022                         1.000000
# Race fastest lap to 2022                                0.636049
# World Championships                                     0.508092
#
# ...

# %% [markdown]
# # Countrys
